# %% [markdown]
# # <img style="float: left; padding-right: 20px; width: 200px" src="attachment:logo.jpg">  IMT 2200 - Introducción a Ciencia de Datos
# **Pontificia Universidad Católica de Chile**<br>
# **Instituto de Ingeniería Matemática y Computacional**<br>
# **Semestre 2023-1**<br>
# **Profesor:** Rodrigo A. Carrasco <br>

# %% [markdown]
# # <h1><center>Tarea 02: Extracción y Transformación de Datos </center></h1>
#
# ## Instrucciones
#
# - Fecha de publicación: viernes 15 de septiembre de 2023.
#
# - Fecha de límite de entrega: viernes 29 de septiembre de 2023, a las 23:59.
#
# - Vía de entrega: Módulo de Tareas en Canvas.
#
# - Esta Tarea debe desarrollarse de manera totalmente *individual*, de acuerdo a lo establecido en la sección de Integridad Académica en el programa del curso.
#
# - La Tarea debe ser desarrollada en lenguaje de programación Python y la entrega en formato Jupyter Notebook.
#
# - El desarrollo del Notebook debe ser claro y ordenado, incluyendo anotaciones (markdown) y comentarios que permitan seguir fácilmente el código y los pasos implementados a los correctores, y siguiendo buenas prácticas de programación. La presentación y claridad del notebook y código forman parte de la evaluación de la tarea.
#
# - Se sugiere hacer consultas y comentarios sobre la Tarea a traves del canal de Tareas en el Foro del curso en Canvas.
#
#
# ## 1. Objetivos de la Tarea
#
# ### 1.1 Objetivo educacional
#
# Esta Tarea tiene como objetivo que los estudiantes desarrollen la capacidad de manejar algunas de las librerías centrales para el desarrollo de Ciencia de Datos, con foco en la extracción y transformación de datos.
#
# En los ejercicios a desarrollar a continuación, usted deberá extraer y transformar datos en distintos formatos, de manera de responder las preguntas de cada parte de la Tarea.
#
# ### 1.2 Pregunta de ciencia de datos
#
# Como comentamos en clases, el objetivo final de las herramientas en ciencia de datos es poder entender mejor un fenómeno o contestar alguna pregunta relevante. En este caso, queremos saber cuáles son las películas más importantes de habla hispana y sus ingresos a nivel mundial.

# %% [markdown]
# ## 2. Datos
#
# Para esta tarea estaremos aprovechando la base de datos de `The Movie Data Base TMDB` que está disponible acá: https://www.themoviedb.org/
#
# ### 2.1 Acceso a la API
#
# La cominucación con TMDB es vía API que requiere una clave única para cada uno/a de ustedes. Para conseguirse su API Key deben crearse una cuenta acá: https://www.themoviedb.org/account/signup y, en la sección de API, crear una nueva aplicación que les dará una API Key única para ustedes.
#
#
# ### 2.2 Documentación
#
# Para poder usar la API, deben revisar la documentación de TMDB que explica cómo se usa cada uno de los elementos. Esto les puede tomar tiempo, así que no dejen para último momento esta tarea.

# %%
# Importación de librerías: importe las siguientes librerías, usando alias comunes
import pandas as pd
import requests
import numpy as np

# %% [markdown]
# ## 3. Desarrollo
#
# Ahora trabajaremos en crear un gráfico con los ingresos de las 20 películas más populares en español que fueron estrenadas en 2022.

# %%
import requests

url = "https://api.themoviedb.org/3/discover/movie?include_adult=true&include_video=false&language=es-ES&page=1&primary_release_year=2022&sort_by=popularity.desc&with_original_language=es&year=2022"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJiMWIyZTdjM2VjZWFkNzU5MmU0MGU3NDYxYTcwZTU5YSIsInN1YiI6IjY1MGI1NmM3MGQ1ZDg1MDExYWVkNjBlNCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.rQcc3VT61R3e4P5-UQJc0biMHYxuZzEX9q454oOEUtg"
}

df_movies = pd.DataFrame(requests.get(url, headers=headers).json()["results"])
df_movies
# Out:
#     adult                     backdrop_path                genre_ids       id  \
# 0   False  /lKK40VrwuLVnjQgmhCfGbDVERBR.jpg                 [27, 14]   912022
# 1   False  /u5nY7pY2Y58o7dSM9cy6NclOV8V.jpg                     [27]  1023313
# 2   False  /nnkiORKM1Q4AU1eWULI1PiWOTLu.jpg             [16, 12, 28]  1029599
# 3   False  /qdFrqXYH6PtyAVlegub7bpoSgro.jpg      [16, 12, 35, 10751]   573171
# 4   False  /2iGUavwv86Hubv3V5Iq4qEQXDfE.jpg             [27, 53, 18]   848058
# 5   False  /4rsomWxlqnHt3muGYK06auhOib6.jpg          [18, 10749, 35]   818647
# 6   False  /xceMtcvhvxvSfZKhCBV367cZRyQ.jpg                     [35]  1034186
# 7   False  /2E6pIbJien7B9yWpaz8Yd2njzUI.jpg                 [18, 27]  1026563
# 8   False  /jgGaaM3bdg18ZGxuMXd2cZihCpx.jpg             [27, 28, 35]   675054
# 9   False  /e5ZMGCPw4HWhA56LD3wqVlmSz3g.jpg                     [99]  1017138
# 10  False  /10c3Hrn1clcSg9PJVl16TARq8Oe.jpg              [10749, 35]   648743
# ...

# %% [markdown]
# ### 3.1 Base de datos de películas (2 puntos)
#
# Estudie cómo se puede acceder a las películar más populares usando la API y filtre su solicitud limitando a películas en el idioma español para el año 2022.
#
# Arme un DataFrame que contenga las 20 películas más populares y revise los campos de cada columna para identificar el tipo de dato que hay en cada una de ellas.
#
# Conteste la siguiente pregunta:
# - ¿Están todos los datos en el formato correcto?
#
# Si alguna de las columnas está en formato incorrecto, preocúpese de corregirla.

# %% [markdown]
# La unica columna que no está en el formato correcto es la columna "release_date", ya que está en formato object. Para corregirla, se debe convertir a formato datetime. Todas las demas columnas estan en su formato correspondiente.

# %%
df_movies["release_date"] = pd.to_datetime(df_movies["release_date"])

# %% [markdown]
# ### 3.2 Primer analisis (0.5 punto)
#
# La columna `vote_average` tiene la evaluación de la película por quienes la han visto. Usando esa información conteste la siguiente pregunta:
# - ¿Cuál fue la película más popular en idioma español que fue estrenada en 2022?

# %%
df_movies[df_movies["vote_average"].max() == df_movies["vote_average"]]
# Out:
#    adult                     backdrop_path            genre_ids      id  \
# 3  False  /qdFrqXYH6PtyAVlegub7bpoSgro.jpg  [16, 12, 35, 10751]  573171
#
#   original_language       original_title  \
# 3                es  Huevitos Congelados
#
#                                             overview  popularity  \
# 3  Sigue las aventuras de Toto y su familia, que ...      62.366
#
#                        poster_path release_date                title  video  \
# 3  /Qotf3QgDqUZEW6pfQl2BPxZCRn.jpg   2022-12-14  Huevitos Congelados  False
#
#    vote_average  vote_count
# 3           7.7         321

# %% [markdown]
# ### 3.3 Información adicional de una película (1.5 puntos)
#
# La base de datos que ha armado tiene alguna información relevante de las películas, pero falta otra, como por ejemplo, las utilidades logradas por la película o su duración. Ahora bien, usando otra URL podemos también pedir todos los detalles que tienen de cada película, usando su `id` como identificador.
#
# Revise la documentación para aprender cómo consegir la información de una película en particular. En la siguiente celda desarrolle un código que nos muestre los datos de una de las películas de la tabla desarrollada en la sección anterior, a su elección. No necesita poner la información en algún formato especial. El JSON crudo es suficiente.

# %%
ids = df_movies["id"]
url = "https://api.themoviedb.org/3/movie/{id_movie}?language=es-ES"

response = requests.get(( link := url.format(id_movie = 573171)), headers=headers).json()
print(link)
# Out:
# https://api.themoviedb.org/3/movie/573171?language=es-ES

# %% [markdown]
# ### 3.4 Complementando los datos (1.5 puntos)
#
# Con lo que aprendió en la pregunta anterior, extienda el DataFrame creado en la sección 3.2 para incorporar la duración de la película (su `runtime`), el presupuesto (su `budget`) y las ganancias (su `revenue`).

# %%
response = [requests.get(url.format(id_movie = i), headers=headers).json() for i in ids]
df = pd.DataFrame({
    "runtime": [i["runtime"] for i in response],
    "budget" : [i["budget"] for i in response],
    "revenue": [i["revenue"] for i in response],
})

# %%
for i in df.columns:
    df_movies[i] = df[i]

# %%
df_movies
# Out:
#     adult                     backdrop_path                genre_ids       id  \
# 0   False  /lKK40VrwuLVnjQgmhCfGbDVERBR.jpg                 [27, 14]   912022
# 1   False  /u5nY7pY2Y58o7dSM9cy6NclOV8V.jpg                     [27]  1023313
# 2   False  /nnkiORKM1Q4AU1eWULI1PiWOTLu.jpg             [16, 12, 28]  1029599
# 3   False  /qdFrqXYH6PtyAVlegub7bpoSgro.jpg      [16, 12, 35, 10751]   573171
# 4   False  /2iGUavwv86Hubv3V5Iq4qEQXDfE.jpg             [27, 53, 18]   848058
# 5   False  /4rsomWxlqnHt3muGYK06auhOib6.jpg          [18, 10749, 35]   818647
# 6   False  /xceMtcvhvxvSfZKhCBV367cZRyQ.jpg                     [35]  1034186
# 7   False  /2E6pIbJien7B9yWpaz8Yd2njzUI.jpg                 [18, 27]  1026563
# 8   False  /jgGaaM3bdg18ZGxuMXd2cZihCpx.jpg             [27, 28, 35]   675054
# 9   False  /e5ZMGCPw4HWhA56LD3wqVlmSz3g.jpg                     [99]  1017138
# 10  False  /10c3Hrn1clcSg9PJVl16TARq8Oe.jpg              [10749, 35]   648743
# ...

# %% [markdown]
# ### 3.5 Analizando la nueva tabla (0.5 puntos)
#
# Analice la nueva tabla que ha creado. ¿Hacen sentido todos los datos que ahí aparecen? Si encuentra que algo no hace sentido, explique por qué no hace sentido y por qué cree que pasó.

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# Los valores de ```runtime``` tienen sentido y se ajustan al estandar de cada pelicula, pero los datos de ```budget``` y ```revenue``` no tienen sentido, principalmente porque una pelicula no puede tener 0 de presupuesto y 0 de ganancias. Puede que existan dos casos del porque esto puede pasar, el primer caso es que los datos esten erroneos y estos fueron remplazados por 0, y el segundo caso es que los datos esten en una unidad de medida, por ejemplo, las peliculas podrian estar el millones de dolares y las que esten por debajo del millon de dolares, quedarian con un numero menor a 1, y al redondear este numero, se transformaria en 0.
